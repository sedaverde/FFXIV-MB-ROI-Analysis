# %%
## Dependencies
import csv
import pandas as pd
import numpy as np

# %%
recipe = pd.read_csv ('https://raw.githubusercontent.com/xivapi/ffxiv-datamining/master/csv/Recipe.csv',header = 1)
recipe
# Out:
#            # Number  CraftType  RecipeLevelTable Item{Result} Amount{Result}  \
# 0      int32  int32  CraftType  RecipeLevelTable         Item           byte
# 1          0      0          0                 0            0              1
# 2          1  10001          1                 1         5056              1
# 3          2  10002          1                 1         2546              1
# 4          3  10003          1                 2         1602              1
# ...      ...    ...        ...               ...          ...            ...
# 10476  34995      0          0                 0            0              0
# 10477  34996      0          0                 0            0              0
# 10478  34997      0          0                 0            0              0
# 10479  34998      0          0                 0            0              0
# 10480  34999      0          0                 0            0              0
#
#       Item{Ingredient}[0] Amount{Ingredient}[0] Item{Ingredient}[1]  \
# 0                    Item                  byte                Item
# 1                       0                     0                   0
# 2                    5106                     2                5107
# 3                    5056                     1                5361
# 4                    5056                     1                5361
# ...                   ...                   ...                 ...
# 10476                   0                     0                   0
# 10477                   0                     0                   0
# 10478                   0                     0                   0
# 10479                   0                     0                   0
# 10480                   0                     0                   0
#
#       Amount{Ingredient}[1]  ...  SecretRecipeBook  Quest CanQuickSynth  \
# 0                      byte  ...  SecretRecipeBook  Quest        bit&02
# 1                         0  ...                 0      0          True
# 2                         1  ...                 0      0          True
# 3                         1  ...                 0      0          True
# 4                         1  ...                 0      0          True
# ...                     ...  ...               ...    ...           ...
# 10476                     0  ...                 0      0         False
# 10477                     0  ...                 0      0         False
# 10478                     0  ...                 0      0         False
# 10479                     0  ...                 0      0         False
# 10480                     0  ...                 0      0         False
#
#         CanHq ExpRewarded Status{Required} Item{Required}  \
# 0      bit&04      bit&08           Status           Item
# 1        True        True                0              0
# 2        True        True                0              0
# 3        True        True                0              0
# 4        True        True                0              0
# ...       ...         ...              ...            ...
# 10476   False       False                0              0
# 10477   False       False                0              0
# 10478   False       False                0              0
# 10479   False       False                0              0
# 10480   False       False                0              0
#
#       IsSpecializationRequired IsExpert PatchNumber
# 0                       bit&10   bit&20      uint16
# 1                        False    False           0
# 2                        False    False           0
# 3                        False    False           0
# 4                        False    False           0
# ...                        ...      ...         ...
# 10476                    False    False           0
# 10477                    False    False           0
# 10478                    False    False           0
# 10479                    False    False           0
# 10480                    False    False           0
#
# [10481 rows x 47 columns]

# %%
recipe = recipe.drop(labels=0, axis=0)
recipe
# Out:
#            # Number CraftType RecipeLevelTable Item{Result} Amount{Result}  \
# 1          0      0         0                0            0              1
# 2          1  10001         1                1         5056              1
# 3          2  10002         1                1         2546              1
# 4          3  10003         1                2         1602              1
# 5          4  10004         1                2         2355              1
# ...      ...    ...       ...              ...          ...            ...
# 10476  34995      0         0                0            0              0
# 10477  34996      0         0                0            0              0
# 10478  34997      0         0                0            0              0
# 10479  34998      0         0                0            0              0
# 10480  34999      0         0                0            0              0
#
#       Item{Ingredient}[0] Amount{Ingredient}[0] Item{Ingredient}[1]  \
# 1                       0                     0                   0
# 2                    5106                     2                5107
# 3                    5056                     1                5361
# 4                    5056                     1                5361
# 5                    5056                     2                5275
# ...                   ...                   ...                 ...
# 10476                   0                     0                   0
# 10477                   0                     0                   0
# 10478                   0                     0                   0
# 10479                   0                     0                   0
# 10480                   0                     0                   0
#
#       Amount{Ingredient}[1]  ... SecretRecipeBook Quest CanQuickSynth  CanHq  \
# 1                         0  ...                0     0          True   True
# 2                         1  ...                0     0          True   True
# 3                         1  ...                0     0          True   True
# 4                         1  ...                0     0          True   True
# 5                         1  ...                0     0          True   True
# ...                     ...  ...              ...   ...           ...    ...
# 10476                     0  ...                0     0         False  False
# 10477                     0  ...                0     0         False  False
# 10478                     0  ...                0     0         False  False
# 10479                     0  ...                0     0         False  False
# 10480                     0  ...                0     0         False  False
#
#       ExpRewarded Status{Required} Item{Required} IsSpecializationRequired  \
# 1            True                0              0                    False
# 2            True                0              0                    False
# 3            True                0              0                    False
# 4            True                0              0                    False
# 5            True                0              0                    False
# ...           ...              ...            ...                      ...
# 10476       False                0              0                    False
# 10477       False                0              0                    False
# 10478       False                0              0                    False
# 10479       False                0              0                    False
# 10480       False                0              0                    False
#
#       IsExpert PatchNumber
# 1        False           0
# 2        False           0
# 3        False           0
# 4        False           0
# 5        False           0
# ...        ...         ...
# 10476    False           0
# 10477    False           0
# 10478    False           0
# 10479    False           0
# 10480    False           0
#
# [10480 rows x 47 columns]

# %%
recipe.dtypes
# Out:
# #                           object
# Number                      object
# CraftType                   object
# RecipeLevelTable            object
# Item{Result}                object
# Amount{Result}              object
# Item{Ingredient}[0]         object
# Amount{Ingredient}[0]       object
# Item{Ingredient}[1]         object
# Amount{Ingredient}[1]       object
# Item{Ingredient}[2]         object
# Amount{Ingredient}[2]       object
# Item{Ingredient}[3]         object
# Amount{Ingredient}[3]       object
# Item{Ingredient}[4]         object
# Amount{Ingredient}[4]       object
# Item{Ingredient}[5]         object
# Amount{Ingredient}[5]       object
# Item{Ingredient}[6]         object
# Amount{Ingredient}[6]       object
# Item{Ingredient}[7]         object
# Amount{Ingredient}[7]       object
# Item{Ingredient}[8]         object
# Amount{Ingredient}[8]       object
# Item{Ingredient}[9]         object
# Amount{Ingredient}[9]       object
# Unnamed: 26                 object
# IsSecondary                 object
# MaterialQualityFactor       object
# DifficultyFactor            object
# QualityFactor               object
# DurabilityFactor            object
# Unnamed: 32                 object
# RequiredCraftsmanship       object
# RequiredControl             object
# QuickSynthCraftsmanship     object
# QuickSynthControl           object
# SecretRecipeBook            object
# Quest                       object
# CanQuickSynth               object
# CanHq                       object
# ExpRewarded                 object
# Status{Required}            object
# Item{Required}              object
# IsSpecializationRequired    object
# IsExpert                    object
# PatchNumber                 object
# dtype: object

# %%
recipe =recipe.rename(columns={'Item{Result}':'Item'})

# %%
recipe1 = recipe.astype({'Number':'int'})

# %%
recipe1.dtypes
# Out:
# #                           object
# Number                       int32
# CraftType                   object
# RecipeLevelTable            object
# Item                        object
# Amount{Result}              object
# Item{Ingredient}[0]         object
# Amount{Ingredient}[0]       object
# Item{Ingredient}[1]         object
# Amount{Ingredient}[1]       object
# Item{Ingredient}[2]         object
# Amount{Ingredient}[2]       object
# Item{Ingredient}[3]         object
# Amount{Ingredient}[3]       object
# Item{Ingredient}[4]         object
# Amount{Ingredient}[4]       object
# Item{Ingredient}[5]         object
# Amount{Ingredient}[5]       object
# Item{Ingredient}[6]         object
# Amount{Ingredient}[6]       object
# Item{Ingredient}[7]         object
# Amount{Ingredient}[7]       object
# Item{Ingredient}[8]         object
# Amount{Ingredient}[8]       object
# Item{Ingredient}[9]         object
# Amount{Ingredient}[9]       object
# Unnamed: 26                 object
# IsSecondary                 object
# MaterialQualityFactor       object
# DifficultyFactor            object
# QualityFactor               object
# DurabilityFactor            object
# Unnamed: 32                 object
# RequiredCraftsmanship       object
# RequiredControl             object
# QuickSynthCraftsmanship     object
# QuickSynthControl           object
# SecretRecipeBook            object
# Quest                       object
# CanQuickSynth               object
# CanHq                       object
# ExpRewarded                 object
# Status{Required}            object
# Item{Required}              object
# IsSpecializationRequired    object
# IsExpert                    object
# PatchNumber                 object
# dtype: object

# %%
# Out:
# #                           0
# Number                      0
# CraftType                   0
# RecipeLevelTable            0
# Item{Result}                0
# Amount{Result}              0
# Item{Ingredient}[0]         0
# Amount{Ingredient}[0]       0
# Item{Ingredient}[1]         0
# Amount{Ingredient}[1]       0
# Item{Ingredient}[2]         0
# Amount{Ingredient}[2]       0
# Item{Ingredient}[3]         0
# Amount{Ingredient}[3]       0
# Item{Ingredient}[4]         0
# Amount{Ingredient}[4]       0
# Item{Ingredient}[5]         0
# Amount{Ingredient}[5]       0
# Item{Ingredient}[6]         0
# Amount{Ingredient}[6]       0
# Item{Ingredient}[7]         0
# Amount{Ingredient}[7]       0
# Item{Ingredient}[8]         0
# Amount{Ingredient}[8]       0
# Item{Ingredient}[9]         0
# Amount{Ingredient}[9]       0
# Unnamed: 26                 0
# IsSecondary                 0
# MaterialQualityFactor       0
# DifficultyFactor            0
# QualityFactor               0
# DurabilityFactor            0
# Unnamed: 32                 0
# RequiredCraftsmanship       0
# RequiredControl             0
# QuickSynthCraftsmanship     0
# QuickSynthControl           0
# SecretRecipeBook            0
# Quest                       0
# CanQuickSynth               0
# CanHq                       0
# ExpRewarded                 0
# Status{Required}            0
# Item{Required}              0
# IsSpecializationRequired    0
# IsExpert                    0
# PatchNumber                 0
# dtype: int64

# %%
recipe = recipe.astype(str)
recipe.dtypes
# Out:
# #                           object
# Number                      object
# CraftType                   object
# RecipeLevelTable            object
# Item{Result}                object
# Amount{Result}              object
# Item{Ingredient}[0]         object
# Amount{Ingredient}[0]       object
# Item{Ingredient}[1]         object
# Amount{Ingredient}[1]       object
# Item{Ingredient}[2]         object
# Amount{Ingredient}[2]       object
# Item{Ingredient}[3]         object
# Amount{Ingredient}[3]       object
# Item{Ingredient}[4]         object
# Amount{Ingredient}[4]       object
# Item{Ingredient}[5]         object
# Amount{Ingredient}[5]       object
# Item{Ingredient}[6]         object
# Amount{Ingredient}[6]       object
# Item{Ingredient}[7]         object
# Amount{Ingredient}[7]       object
# Item{Ingredient}[8]         object
# Amount{Ingredient}[8]       object
# Item{Ingredient}[9]         object
# Amount{Ingredient}[9]       object
# Unnamed: 26                 object
# IsSecondary                 object
# MaterialQualityFactor       object
# DifficultyFactor            object
# QualityFactor               object
# DurabilityFactor            object
# Unnamed: 32                 object
# RequiredCraftsmanship       object
# RequiredControl             object
# QuickSynthCraftsmanship     object
# QuickSynthControl           object
# SecretRecipeBook            object
# Quest                       object
# CanQuickSynth               object
# CanHq                       object
# ExpRewarded                 object
# Status{Required}            object
# Item{Required}              object
# IsSpecializationRequired    object
# IsExpert                    object
# PatchNumber                 object
# dtype: object
