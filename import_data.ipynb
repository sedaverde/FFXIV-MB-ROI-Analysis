# %%
## Dependencies
import csv
import pandas as pd
import numpy as np

# %%
## Open recipe.csv from xivapi/ffxiv datamining repo; this is the information for all craftable items in ffxiv
recipe = pd.read_csv ('https://raw.githubusercontent.com/xivapi/ffxiv-datamining/master/csv/Recipe.csv',header = 1)
recipe
# Out:
#            # Number  CraftType  RecipeLevelTable Item{Result} Amount{Result}  \
# 0      int32  int32  CraftType  RecipeLevelTable         Item           byte
# 1          0      0          0                 0            0              1
# 2          1  10001          1                 1         5056              1
# 3          2  10002          1                 1         2546              1
# 4          3  10003          1                 2         1602              1
# ...      ...    ...        ...               ...          ...            ...
# 10476  34995      0          0                 0            0              0
# 10477  34996      0          0                 0            0              0
# 10478  34997      0          0                 0            0              0
# 10479  34998      0          0                 0            0              0
# 10480  34999      0          0                 0            0              0
#
#       Item{Ingredient}[0] Amount{Ingredient}[0] Item{Ingredient}[1]  \
# 0                    Item                  byte                Item
# 1                       0                     0                   0
# 2                    5106                     2                5107
# 3                    5056                     1                5361
# 4                    5056                     1                5361
# ...                   ...                   ...                 ...
# 10476                   0                     0                   0
# 10477                   0                     0                   0
# 10478                   0                     0                   0
# 10479                   0                     0                   0
# 10480                   0                     0                   0
#
#       Amount{Ingredient}[1]  ...  SecretRecipeBook  Quest CanQuickSynth  \
# 0                      byte  ...  SecretRecipeBook  Quest        bit&02
# 1                         0  ...                 0      0          True
# 2                         1  ...                 0      0          True
# 3                         1  ...                 0      0          True
# 4                         1  ...                 0      0          True
# ...                     ...  ...               ...    ...           ...
# 10476                     0  ...                 0      0         False
# 10477                     0  ...                 0      0         False
# 10478                     0  ...                 0      0         False
# 10479                     0  ...                 0      0         False
# 10480                     0  ...                 0      0         False
#
#         CanHq ExpRewarded Status{Required} Item{Required}  \
# 0      bit&04      bit&08           Status           Item
# 1        True        True                0              0
# 2        True        True                0              0
# 3        True        True                0              0
# 4        True        True                0              0
# ...       ...         ...              ...            ...
# 10476   False       False                0              0
# 10477   False       False                0              0
# 10478   False       False                0              0
# 10479   False       False                0              0
# 10480   False       False                0              0
#
#       IsSpecializationRequired IsExpert PatchNumber
# 0                       bit&10   bit&20      uint16
# 1                        False    False           0
# 2                        False    False           0
# 3                        False    False           0
# 4                        False    False           0
# ...                        ...      ...         ...
# 10476                    False    False           0
# 10477                    False    False           0
# 10478                    False    False           0
# 10479                    False    False           0
# 10480                    False    False           0
#
# [10481 rows x 47 columns]

# %%
## Drop row that identified the data types for each column
recipe = recipe.drop(labels=0, axis=0)
recipe
# Out:
#            # Number CraftType RecipeLevelTable Item{Result} Amount{Result}  \
# 1          0      0         0                0            0              1
# 2          1  10001         1                1         5056              1
# 3          2  10002         1                1         2546              1
# 4          3  10003         1                2         1602              1
# 5          4  10004         1                2         2355              1
# ...      ...    ...       ...              ...          ...            ...
# 10476  34995      0         0                0            0              0
# 10477  34996      0         0                0            0              0
# 10478  34997      0         0                0            0              0
# 10479  34998      0         0                0            0              0
# 10480  34999      0         0                0            0              0
#
#       Item{Ingredient}[0] Amount{Ingredient}[0] Item{Ingredient}[1]  \
# 1                       0                     0                   0
# 2                    5106                     2                5107
# 3                    5056                     1                5361
# 4                    5056                     1                5361
# 5                    5056                     2                5275
# ...                   ...                   ...                 ...
# 10476                   0                     0                   0
# 10477                   0                     0                   0
# 10478                   0                     0                   0
# 10479                   0                     0                   0
# 10480                   0                     0                   0
#
#       Amount{Ingredient}[1]  ... SecretRecipeBook Quest CanQuickSynth  CanHq  \
# 1                         0  ...                0     0          True   True
# 2                         1  ...                0     0          True   True
# 3                         1  ...                0     0          True   True
# 4                         1  ...                0     0          True   True
# 5                         1  ...                0     0          True   True
# ...                     ...  ...              ...   ...           ...    ...
# 10476                     0  ...                0     0         False  False
# 10477                     0  ...                0     0         False  False
# 10478                     0  ...                0     0         False  False
# 10479                     0  ...                0     0         False  False
# 10480                     0  ...                0     0         False  False
#
#       ExpRewarded Status{Required} Item{Required} IsSpecializationRequired  \
# 1            True                0              0                    False
# 2            True                0              0                    False
# 3            True                0              0                    False
# 4            True                0              0                    False
# 5            True                0              0                    False
# ...           ...              ...            ...                      ...
# 10476       False                0              0                    False
# 10477       False                0              0                    False
# 10478       False                0              0                    False
# 10479       False                0              0                    False
# 10480       False                0              0                    False
#
#       IsExpert PatchNumber
# 1        False           0
# 2        False           0
# 3        False           0
# 4        False           0
# 5        False           0
# ...        ...         ...
# 10476    False           0
# 10477    False           0
# 10478    False           0
# 10479    False           0
# 10480    False           0
#
# [10480 rows x 47 columns]

# %%
## Drop columns that are not needed
recipe = recipe.drop(recipe.columns[[26,28,29,31,32,38,41,46]],axis = 1)

# %%
## Verify the data types that the data was imported into as, in order to identify those needing updating
recipe.dtypes
# Out:
# #                           object
# Number                      object
# CraftType                   object
# RecipeLevelTable            object
# Item{Result}                object
# Amount{Result}              object
# Item{Ingredient}[0]         object
# Amount{Ingredient}[0]       object
# Item{Ingredient}[1]         object
# Amount{Ingredient}[1]       object
# Item{Ingredient}[2]         object
# Amount{Ingredient}[2]       object
# Item{Ingredient}[3]         object
# Amount{Ingredient}[3]       object
# Item{Ingredient}[4]         object
# Amount{Ingredient}[4]       object
# Item{Ingredient}[5]         object
# Amount{Ingredient}[5]       object
# Item{Ingredient}[6]         object
# Amount{Ingredient}[6]       object
# Item{Ingredient}[7]         object
# Amount{Ingredient}[7]       object
# Item{Ingredient}[8]         object
# Amount{Ingredient}[8]       object
# Item{Ingredient}[9]         object
# Amount{Ingredient}[9]       object
# IsSecondary                 object
# QualityFactor               object
# RequiredCraftsmanship       object
# RequiredControl             object
# QuickSynthCraftsmanship     object
# QuickSynthControl           object
# SecretRecipeBook            object
# CanQuickSynth               object
# CanHq                       object
# Status{Required}            object
# Item{Required}              object
# IsSpecializationRequired    object
# IsExpert                    object
# dtype: object

# %%
## Simplify/clarify column names; ItemID (DBkey)
recipe =recipe.rename(columns={'Number':'RecipeID','RecipeLevelTable':'Level','Item{Result}':'ItemID','Amount{Result}':'Quant','Item{Ingredient}[0]':'Mat0','Item{Ingredient}[1]':'Mat1','Item{Ingredient}[2]':'Mat2','Item{Ingredient}[3]':'Mat3','Item{Ingredient}[4]':'Mat4','Item{Ingredient}[5]':'Mat5','Item{Ingredient}[6]':'Mat6','Item{Ingredient}[7]':'Mat7','Item{Ingredient}[8]':'Mat8','Item{Ingredient}[9]':'Mat9','Amount{Ingredient}[0]':'Quant0','Amount{Ingredient}[1]':'Quant1','Amount{Ingredient}[2]':'Quant2','Amount{Ingredient}[3]':'Quant3','Amount{Ingredient}[4]':'Quant4','Amount{Ingredient}[5]':'Quant5','Amount{Ingredient}[6]':'Quant6','Amount{Ingredient}[7]':'Quant7','Amount{Ingredient}[8]':'Quant8','Amount{Ingredient}[9]':'Quant9','RequiredCraftsmanship':'Craftsmanship','RequiredControl':'Control','QuickSynthCraftsmanship':'QSCraftsmanship','QuickSynthControl':'QSControl','SecretRecipeBook':'Book','CanQuickSynth':'QS','CanHq':'HQ','IsSpecializationRequired':'Specialized','IsExpert':'Expert'})

# %%
## Set correct data types
recipe = recipe.astype({'RecipeID':'int','CraftType':'byte','Level':'byte','ItemID':'int','Quant':'byte','Mat0':'int','Mat1':'int','Mat2':'int','Mat3':'int','Mat4':'int','Mat5':'int','Mat6':'int','Mat7':'int','Mat8':'int','Mat9':'int','Quant0':'byte','Quant1':'byte','Quant2':'byte','Quant3':'byte','Quant4':'byte','Quant5':'byte','Quant6':'byte','Quant7':'byte','Quant8':'byte','Quant9':'byte','Craftsmanship':'uint16','Control':'uint16','QSCraftsmanship':'uint16','QSControl':'uint16','Book':'byte','QualityFactor':'int','Status{Required}':'int','Item{Required}':'int'})

# %%
recipe.dtypes
# Out:
# #                   object
# RecipeID             int32
# CraftType             int8
# Level                 int8
# ItemID               int32
# Quant                 int8
# Mat0                 int32
# Quant0                int8
# Mat1                 int32
# Quant1                int8
# Mat2                 int32
# Quant2                int8
# Mat3                 int32
# Quant3                int8
# Mat4                 int32
# Quant4                int8
# Mat5                 int32
# Quant5                int8
# Mat6                 int32
# Quant6                int8
# Mat7                 int32
# Quant7                int8
# Mat8                 int32
# Quant8                int8
# Mat9                 int32
# Quant9                int8
# IsSecondary         object
# QualityFactor        int32
# Craftsmanship       uint16
# Control             uint16
# QSCraftsmanship     uint16
# QSControl           uint16
# Book                  int8
# QS                  object
# HQ                  object
# Status{Required}     int32
# Item{Required}       int32
# Specialized         object
# Expert              object
# dtype: object

# %%
## Convert object to Boolean
recipe = recipe.replace({'True': True, 'False': False})

# %%
recipe.dtypes
# Out:
# #                   object
# RecipeID             int32
# CraftType             int8
# Level                 int8
# ItemID               int32
# Quant                 int8
# Mat0                 int32
# Quant0                int8
# Mat1                 int32
# Quant1                int8
# Mat2                 int32
# Quant2                int8
# Mat3                 int32
# Quant3                int8
# Mat4                 int32
# Quant4                int8
# Mat5                 int32
# Quant5                int8
# Mat6                 int32
# Quant6                int8
# Mat7                 int32
# Quant7                int8
# Mat8                 int32
# Quant8                int8
# Mat9                 int32
# Quant9                int8
# IsSecondary           bool
# QualityFactor        int32
# Craftsmanship       uint16
# Control             uint16
# QSCraftsmanship     uint16
# QSControl           uint16
# Book                  int8
# QS                    bool
# HQ                    bool
# Status{Required}     int32
# Item{Required}       int32
# Specialized           bool
# Expert                bool
# dtype: object

# %%
## Open item.csv from xivapi/ffxiv datamining repo; this is the information for all items in ffxiv; only importing certain columns
item = pd.read_csv("https://raw.githubusercontent.com/xivapi/ffxiv-datamining/master/csv/Item.csv",header = 1,usecols = ['#','Description','Name','StackSize','Price{Mid}','Price{Low}','CanBeHq','IsDyeable','ClassJob{Use}','IsUntradable'])
item
# Out:
# C:\Users\cplnrl\Anaconda3\envs\PythonV1\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,21,23,26,27,28,29,50) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            #                                        Description        Name  \
# 0      int32                                                str         str
# 1          0                                                NaN         NaN
# 2          1                         Standard Eorzean currency.         Gil
# 3          2  A tiny crystalline manifestation of aetheric f...  Fire Shard
# 4          3  A tiny crystalline manifestation of aetheric i...   Ice Shard
# ...      ...                                                ...         ...
# 36697  36696                                                NaN         NaN
# 36698  36697                                                NaN         NaN
# 36699  36698                                                NaN         NaN
# 36700  36699                                                NaN         NaN
# 36701  36700                                                NaN         NaN
#
#        StackSize IsUntradable Price{Mid} Price{Low} CanBeHq IsDyeable  \
# 0         uint32       bit&02     uint32     uint32  bit&10    bit&20
# 1              1        False          0          0   False     False
# 2      999999999        False          0          0   False     False
# 3           9999        False          9          0   False     False
# 4           9999        False          9          0   False     False
# ...          ...          ...        ...        ...     ...       ...
# 36697          0        False          0          0   False     False
# 36698          0        False          0          0   False     False
# 36699          0        False          0          0   False     False
# 36700          0        False          0          0   False     False
# 36701          0        False          0          0   False     False
#
#       ClassJob{Use}
# 0          ClassJob
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 36697             0
# 36698             0
# 36699             0
# 36700             0
# 36701             0
#
# [36702 rows x 10 columns]

# %%
## Drop row that identified the data types for each column
item = item.drop(labels=0, axis=0)
## Dropping items that begin with the word Dated and items that are not tradable
item = item[item['Name'].str.contains("Dated ")==False]
item = item[item['IsUntradable'].str.contains("True")==False]
## Rename # column to ItemID (DB key)
item = item.rename(columns={'#':'ItemID','Price{Mid}':'PriceMid','Price{Low}':'PriceLow','ClassJob{Use}':'ClassJobUse'})
item
# Out:
#      ItemID                                        Description  \
# 2         1                         Standard Eorzean currency.
# 3         2  A tiny crystalline manifestation of aetheric f...
# 4         3  A tiny crystalline manifestation of aetheric i...
# 5         4  A tiny crystalline manifestation of aetheric w...
# 6         5  A tiny crystalline manifestation of aetheric e...
# ...     ...                                                ...
# 8185   8184  Onion Prince seeds suitable for garden cultiva...
# 8186   8185  Eggplant Knight seeds suitable for garden cult...
# 8187   8186  Garlic Jester seeds suitable for garden cultiv...
# 8188   8187  Tomato King seeds suitable for garden cultivat...
# 8189   8188  Mandragora Queen seeds suitable for garden cul...
#
#                         Name  StackSize IsUntradable PriceMid PriceLow  \
# 2                        Gil  999999999        False        0        0
# 3                 Fire Shard       9999        False        9        0
# 4                  Ice Shard       9999        False        9        0
# 5                 Wind Shard       9999        False        9        0
# 6                Earth Shard       9999        False        9        0
# ...                      ...        ...          ...      ...      ...
# 8185      Onion Prince Seeds        999        False      332        1
# 8186   Eggplant Knight Seeds        999        False      332        1
# 8187     Garlic Jester Seeds        999        False      332        1
# 8188       Tomato King Seeds        999        False      332        1
# 8189  Mandragora Queen Seeds        999        False      332        1
#
#      CanBeHq IsDyeable ClassJobUse
# 2      False     False           0
# 3      False     False           0
# 4      False     False           0
# 5      False     False           0
# 6      False     False           0
# ...      ...       ...         ...
# 8185   False     False           0
# 8186   False     False           0
# 8187   False     False           0
# 8188   False     False           0
# 8189   False     False           0
#
# [3834 rows x 10 columns]

# %%
## Set correct data types
item = item.astype({'ItemID':'int','StackSize':'int','Description':'string','Name':'string','PriceLow':'int','PriceMid':'int','ClassJobUse':'int'})
item = item.replace({'True': True, 'False': False})

# %%
item.dtypes
# Out:
# ItemID           int32
# Description     string
# Name            string
# StackSize        int32
# IsUntradable      bool
# PriceMid         int32
# PriceLow         int32
# CanBeHq           bool
# IsDyeable         bool
# ClassJobUse      int32
# dtype: object

# %%
recipe.isna().sum()
# Out:
# ItemID             0
# Description     1504
# Name               0
# StackSize          0
# IsUntradable       0
# PriceMid           0
# PriceLow           0
# CanBeHq            0
# IsDyeable          0
# ClassJobUse        0
# dtype: int64

# %%
item.isna().sum()
# Out:
# ItemID             0
# Description     1504
# Name               0
# StackSize          0
# IsUntradable       0
# PriceMid           0
# PriceLow           0
# CanBeHq            0
# IsDyeable          0
# ClassJobUse        0
# dtype: int64
